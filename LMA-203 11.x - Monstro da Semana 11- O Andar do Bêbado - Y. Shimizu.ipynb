# %% [markdown]
# ## Introdução
#
# Visando analisar o sorteio aleatório de direções num plano cartesiano, simulamos uma situação em que o senhor Rê, após 7 shots de tequila pura, caminhava num plano infinito apenas nas direções norte, sul leste e oeste, exatamente um metro por minuto,durante mil minutos. Plotamos gráficos $X \times Y$, $Tempo\times X$ e $Tempo\times Y$ para visualizar essa trajetória. Feito isso, também simulamos a mesma situação em mil universos paralelos, e calculamos a distância da posição do senhor Rê a cada minuto, tirando o valor esperado da posição nessas mil simulações.

# %% [markdown]
# ## Metodologia

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Primeiramente, definimos uma função que sorteia a direção em que o bebum andará:

# %%
def sorteia_direcao():
    return random.choice(["norte", "sul", "leste", "oeste"])

sorteia_direcao()
# Out:
# 'oeste'

# %% [markdown]
# Feito isso, utilizaremos `sorteia_direcao()` para simular o andar do bêbado em um plano, retornando uma lista com as direções seguidas pelo bêbado a cada minuto, e listas de posição a cada eixo, sendo norte definido como y+1, sul como x-1, leste como x+1 e oeste como x-1.

# %%
def andar_do_bebado(n):
    x = 0
    y = 0
    x_list=[0]
    y_list=[0]
    direcoes = []

    for _ in range(n):
        direcao = sorteia_direcao()
        direcoes.append(direcao)
        
        if direcao == "norte":
            y+=1
        elif direcao == "sul":
            y-=1
        elif direcao =="leste":
            x+= 1
        elif direcao =="oeste":
            x-=1
            
        x_list.append(x)
        y_list.append(y)

    return direcoes, x_list, y_list

# %%
direcoes, x, y = andar_do_bebado(1000)

print(direcoes)
# Out:
# ['oeste', 'leste', 'norte', 'leste', 'leste', 'sul', 'norte', 'norte', 'sul', 'norte', 'oeste', 'norte', 'sul', 'sul', 'leste', 'oeste', 'leste', 'leste', 'sul', 'sul', 'sul', 'leste', 'sul', 'norte', 'sul', 'norte', 'oeste', 'norte', 'leste', 'leste', 'leste', 'norte', 'leste', 'leste', 'leste', 'sul', 'leste', 'norte', 'oeste', 'leste', 'sul', 'leste', 'oeste', 'oeste', 'oeste', 'leste', 'sul', 'leste', 'oeste', 'oeste', 'sul', 'leste', 'norte', 'oeste', 'oeste', 'oeste', 'norte', 'sul', 'sul', 'oeste', 'oeste', 'sul', 'leste', 'sul', 'norte', 'norte', 'leste', 'sul', 'oeste', 'oeste', 'oeste', 'leste', 'leste', 'leste', 'oeste', 'norte', 'leste', 'norte', 'norte', 'leste', 'oeste', 'norte', 'oeste', 'norte', 'leste', 'leste', 'leste', 'norte', 'sul', 'leste', 'leste', 'sul', 'sul', 'leste', 'oeste', 'leste', 'sul', 'leste', 'sul', 'oeste', 'leste', 'norte', 'oeste', 'oeste', 'leste', 'norte', 'norte', 'norte', 'norte', 'norte', 'norte', 'oeste', 'oeste', 'oeste', 'sul', 'leste', 'norte', 'norte', 'leste', 'oeste', 'norte', 'oeste', 'sul', 'norte', 'oeste', 'sul', 'norte', 'oeste', 'leste', 'norte', 'oeste', 'oeste', 'norte', 'sul', 'sul', 'oeste', 'leste', 'oeste', 'leste', 'sul', 'sul', 'norte', 'norte', 'oeste', 'leste', 'norte', 'norte', 'leste', 'leste', 'sul', 'leste', 'oeste', 'sul', 'norte', 'norte', 'norte', 'norte', 'leste', 'sul', 'sul', 'oeste', 'sul', 'leste', 'leste', 'leste', 'oeste', 'norte', 'norte', 'oeste', 'oeste', 'norte', 'oeste', 'norte', 'oeste', 'oeste', 'leste', 'leste', 'oeste', 'sul', 'norte', 'leste', 'norte', 'norte', 'sul', 'leste', 'leste', 'sul', 'sul', 'norte', 'norte', 'oeste', 'norte', 'oeste', 'leste', 'oeste', 'sul', 'sul', 'sul', 'oeste', 'oeste', 'oeste', 'leste', 'leste', 'oeste', 'oeste', 'oeste', 'leste', 'oeste', 'norte', 'sul', 'norte', 'oeste', 'oeste', 'sul', 'leste', 'sul', 'norte', 'sul', 'oeste', 'leste', 'norte', 'norte', 'sul', 'sul', 'sul', 'sul', 'leste', 'leste', 'leste', 'norte', 'oeste', 'leste', 'norte', 'leste', 'oeste', 'sul', 'norte', 'sul', 'oeste', 'sul', 'leste', 'norte', 'leste', 'sul', 'leste', 'sul', 'leste', 'oeste', 'sul', 'leste', 'sul', 'oeste', 'sul', 'sul', 'oeste', 'oeste', 'leste', 'sul', 'oeste', 'norte', 'leste', 'sul', 'oeste', 'norte', 'norte', 'oeste', 'norte', 'norte', 'oeste', 'sul', 'norte', 'oeste', 'norte', 'oeste', 'oeste', 'norte', 'norte', 'oeste', 'leste', 'norte', 'oeste', 'oeste', 'sul', 'oeste', 'oeste', 'leste', 'leste', 'sul', 'oeste', 'oeste', 'leste', 'leste', 'sul', 'sul', 'oeste', 'leste', 'sul', 'leste', 'sul', 'leste', 'sul', 'leste', 'norte', 'oeste', 'oeste', 'sul', 'leste', 'leste', 'oeste', 'sul', 'oeste', 'norte', 'norte', 'norte', 'leste', 'norte', 'leste', 'oeste', 'oeste', 'norte', 'oeste', 'oeste', 'oeste', 'norte', 'oeste', 'leste', 'leste', 'sul', 'oeste', 'norte', 'oeste', 'leste', 'oeste', 'leste', 'oeste', 'oeste', 'leste', 'leste', 'oeste', 'sul', 'sul', 'sul', 'sul', 'sul', 'leste', 'leste', 'leste', 'sul', 'norte', 'norte', 'oeste', 'oeste', 'norte', 'leste', 'leste', 'oeste', 'sul', 'sul', 'leste', 'leste', 'norte', 'oeste', 'oeste', 'leste', 'norte', 'norte', 'sul', 'oeste', 'sul', 'leste', 'norte', 'norte', 'sul', 'sul', 'oeste', 'norte', 'leste', 'norte', 'leste', 'oeste', 'norte', 'sul', 'norte', 'leste', 'sul', 'sul', 'sul', 'sul', 'norte', 'sul', 'norte', 'norte', 'norte', 'sul', 'oeste', 'sul', 'norte', 'sul', 'sul', 'leste', 'leste', 'leste', 'leste', 'norte', 'norte', 'oeste', 'oeste', 'norte', 'leste', 'oeste', 'sul', 'norte', 'norte', 'sul', 'oeste', 'leste', 'sul', 'sul', 'sul', 'oeste', 'sul', 'norte', 'leste', 'sul', 'oeste', 'leste', 'oeste', 'leste', 'oeste', 'oeste', 'sul', 'oeste', 'oeste', 'leste', 'norte', 'sul', 'sul', 'norte', 'oeste', 'sul', 'norte', 'oeste', 'leste', 'leste', 'leste', 'leste', 'sul', 'norte', 'sul', 'oeste', 'oeste', 'oeste', 'leste', 'sul', 'leste', 'norte', 'norte', 'oeste', 'norte', 'oeste', 'sul', 'sul', 'norte', 'oeste', 'leste', 'oeste', 'oeste', 'oeste', 'leste' ...

# %% [markdown]
# Com as listas x e y, plotaremos os gráficos $X \times Y$, $Tempo\times X$ e $Tempo\times Y$ para visualizar a trajetória feita pelo senhor Rê.

# %%
plt.plot(x,y, marker = ".", color = "yellowgreen")
plt.grid(True)
plt.xlabel("Eixo x (m)")
plt.ylabel("Eixo y (m)")
plt.title ("Andar do bêbado no plano")
# Out:
# Text(0.5, 1.0, 'Andar do bêbado no plano')

# %%
t = range(1001)

plt.plot(t,x, marker = ".", color = "yellow")
plt.grid(True)
plt.xlabel("Tempo (min)")
plt.ylabel("Eixo x (m)")
plt.title ("Andar do bêbado no eixo x em função do tempo")
# Out:
# Text(0.5, 1.0, 'Andar do bêbado no eixo x em função do tempo')

# %%
plt.plot(t,y, marker = ".", color = "b")
plt.grid(True)
plt.xlabel("Tempo (min)")
plt.ylabel("Eixo y (m)")
plt.title ("Andar do bêbado no eixo y em função do tempo")
# Out:
# Text(0.5, 1.0, 'Andar do bêbado no eixo y em função do tempo')

# %% [markdown]
# Partimos, agora, para o calculo do valor esperado das distâncias a cada tempo.
#
# Primeiramente, definimos uma função `d(t)` que calcula o valor esperado da distância a cada minuto para uma simulação. Feito isso, definimos uma função que calcula o `d(t)` para diversas simulações e retorna o valor esparado de `d(t)` para cada minuto. Aqui, consideramos que o valor esperado é equivalente à média.

# %%
def d(t):
    direcoes, x, y = andar_do_bebado(t)
    x = np.array(x)
    y = np.array(y)
    distancias = (x**2 + y**2)**(1/2)
    return distancias

d(1000)
# Out:
# array([ 0.        ,  1.        ,  0.        , ..., 68.02940541,
#        68.00735254, 67.00746227])

# %%
def val_esp_d(t, n_trajetos):
    
    distancias = np.zeros((n_trajetos, t+1))
    
    for n in range(n_trajetos):
        distancias[n] = d(t)
        
    resultado = np.zeros((1, t))        
    for m in range(t):
        soma = 0
        for n in range(n_trajetos):
            soma+= distancias[n][m]
        resultado[0][m] = soma
        
    resultado = resultado/n_trajetos
    resultado = list(resultado[0])
    return resultado
        
resultado = val_esp_d(1000, 1000)
print(resultado)
# Out:
# [0.0, 1.0, 1.2144204896855375, 1.571053355607416, 1.7268794630567779, 1.9982550526344693, 2.1250194243378244, 2.3567466453320147, 2.5052454499377026, 2.680362230929473, 2.7832213610840064, 2.94458411867358, 3.030987675526375, 3.1909831593577462, 3.292844483210447, 3.4215928910723727, 3.5333296332757627, 3.636085683936874, 3.7338462893256157, 3.8647608518176892, 3.9167614004067914, 4.036326582300703, 4.113442936624536, 4.196163594355159, 4.272909697098739, 4.353454142190648, 4.426208125654003, 4.543638869507582, 4.6329682278934925, 4.723327805803739, 4.795818797106227, 4.8657094357928665, 4.930388375484615, 5.078074628922638, 5.159822715560022, 5.282580362884808, 5.36270944261688, 5.456031302665526, 5.527243032168959, 5.631764658471252, 5.686270619938314, 5.786865100458993, 5.840059375470253, 5.932079279753924, 5.994254113056356, 6.076294534326774, 6.125048916649854, 6.174329578514485, 6.212479790923225, 6.301532260983845, 6.336043001551393, 6.4001642418872615, 6.454639553324157, 6.526097448109382, 6.597053991380419, 6.665972222686868, 6.723755440531583, 6.811314162251943, 6.87439626237124, 6.9271870666102044, 6.998858531292324, 7.031446849403653, 7.109900216925324, 7.207992428187866, 7.25920995007211, 7.331338306330707, 7.397314412259301, 7.461730588214584, 7.5168688491886595, 7.622844505082889, 7.669861862656648, 7.702440349947336, 7.7296322686950605, 7.787665622531904, 7.85305764892545, 7.910289937998645, 7.952517063953292, 7.995405737131733, 8.030459018584978, 8.080516772021213, 8.111797839137038, 8.189782142924408, 8.227632067815813, 8.264945970944094, 8.3120182691435, 8.364886011066513, 8.446321317096064, 8.465106257452495, 8.522316501917764, 8.546280558890963, 8.577349715682976, 8.624168987345252, 8.702288187821077, 8.791344226978467, 8.845232736674118, 8.914744102973145, 8.934737652118695, 8.997630031846983, 8.985770122096316, 9.046421948256745, 9.068376774044607, 9.15646266580044, 9.13951314289776, 9.212903062699073, 9.273854524016008, 9.298184056331223, 9.323575359019664, 9.344730551086549, 9.36169651975167, 9.422507776716499, 9.450971303112487, 9.485719699229804, 9.494705387406036, 9.524357665095055, 9.540770861060055, 9.608191600192008, 9.622664688644548, 9.665133728045406, 9.74584198833645, 9.762906348917536, 9.794552241215444, 9.831139645471534, 9.890324080860186, 9.917774972126944, 9.960329022167908, 9.942750290687934, 9.985313422826586, 10.03138213531873, 10.076428987377778, 10.124988394755043, 10.188133577612692, 10.221320224756113, 10.260042196652124, 10.324757601987406, 10.393242924183554, 10.408293541468439, 10.4533910718934, 10.486385749074007, 10.521880947633129, 10.549916609095481, 10.594245040201967, 10.622200072532975, 10.67206474066519, 10.717233086967623, 10.737697877179992, 10.801704299803639, 10.836148695285356, 10.880740073796849, 10.897459080750222, 10.910069566043795, 10.93680315836953, 10.999663661612981, 11.020584157813825, 11.06704396740276, 11.113533137602467, 11.156099477967697, 11.20101352055181, 11.243447768857063, 11.265188386137202, 11.28453095653186, 11.336052403105384, 11.40237863434803, 11.41737284435757, 11.408057988003526, 11.44123254536243, 11.48958614989449, 11.514921019656066, 11.531689539526148, 11.565843883789073, 11.610150812649424, 11.6249947911562, 11.68461660218145, 11.718070911556511, 11.720814564127586, 11.749583619770558, 11.77146002585081, 11.792127403460466, 11.835125546037418, 11.820822975757263, 11.876825874345805, 11.892133339396766, 11.930940282517472, 11.95502132791931, 11.98758906992824, 12.043411184254218, 12.067909840995796, 12.080715896471693, 12.101077120886451, 12.11714230402277, 12.151963250097582, 12.181713374368384, 12.233844022446286, 12.285899776678555, 12.28818138165359, 12.287802251219373, 12.315154039979578, 12.34306301944313, 12.379656849435888, 12.393534775581575, 12.433868408694627, 12.440298859709234, 12.497013436027443, 12.51715999434445, 12.539167917411962, 12.588507001722933, 12.607323361387483, 12.589128326973963, 12.628608591051943, 12.67105 ...

# %% [markdown]
# Calculando, então, o valor esperado de `d(t)` para $t=1000$ e $n_{trajetos}=1000$, podemos plotar o seguinte gráfico:

# %%
plt.plot(range(1000), resultado, marker=".", color = "indigo")
plt.grid(True)
plt.xlabel("Tempo (min)")
plt.ylabel("$E[d(t)]$")
plt.title ("Valor esperado da distância para $t = 1000, \mathrm{n_{trajetos}} = 1000$")
# Out:
# Text(0.5, 1.0, 'Valor esperado da distância para $t = 1000, \\mathrm{n_{trajetos}} = 1000$')

# %% [markdown]
# ## Discussões
#
# Pelo gráficos de $X \times Y$, $Tempo\times X$ e $Tempo\times Y$, podemos notar como a posição do bebum de dá de maneira distribuída pelos quatro quadrantes do plano no qual caminha,o que se dá pelo sorteio aleatório de posições com mesma probabilidade - vista também, analisando o movimento em cada eixo, com posições tanto positivas quanto negativas.
#
# Sobre o valor esperado da distâcia euclidiana $E[d(t)]$, podemos perceber um comportamento uniforme e similar a uma função raíz, o que é esperado, considerando que a distância euclidiana é dada por
#
# $$
# d(t) = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}, (x_1, y_1) = (0,0)
# $$
#
# $$
# d(t) = \sqrt{x_2^2 + y_2^2}
# $$
#
# e o valor esperado é dado pela média de $d(t)$ para mil simulações.

# %% [markdown]
# ## Conclusões
#
# Com as simulações realizadas, foi possível perceber a aleatoriedade do sorteio com mesma probabilidades. Além disso, pudemos concluir que o valor esperado de distâncias euclidianas para mesmo valor de tempo segue o comportamento de uma função raíz devido ao cálculo da distância euclidiana.
#
# Desse modo, concluímos que as simulações foram bem sucedidas!

# %% [markdown]
# ### Referências
#
# CASSAR, DR. LMA-203 2.0 - População, amostra e correlação. Microsoft Teams, T03-LMA-203 - Probabilidade e Estatística, Material de Aula.
#
# CASSAR, DR. LMA-203 3.0 - Simulação e experimentos computacionais. Microsoft Teams, T03-LMA-203 - Probabilidade e Estatística, Material de Aula.
